# %% [markdown]
# Trying to make a FCN to predict dihedral angles. Some of the code adapted from Jeppe's openprotein.

# %%
import numpy as np
import torch
import imp
import re
from torch.nn.utils.rnn import pad_sequence

# %%
aa_id_dict = {'A': 0, 'C': 1, 'D': 2, 'E': 3, 'F': 4, 'G': 5, 'H': 6, 'I': 7,
              'K': 8, 'L': 9, 'M': 10, 'N': 11, 'P': 12, 'Q': 13, 'R': 14, 
              'S': 15, 'T': 16, 'V': 17, 'W': 18, 'Y': 19}

# %%
def aa_to_onehot(aa_str, aa_to_nr, mask=None):
    if mask!=None:
        mask_ind = np.asarray([x=='+' for x in mask])*1
        mask_ind = np.nonzero(mask_ind)
        aa_str = "".join([aa_str[x] for x in mask_ind[0]]) # because it gets put in another list
    init_array = np.zeros( (len(aa_to_nr.keys()), len(aa_str)) )
    for i,j in enumerate(aa_str):
        init_array[aa_to_nr[j], i] = 1
    return(init_array)

# %%
def read_proteinnet_file(file, stop_at=1000, verbose=True):
    protein_dict = {}
    with open(file) as input:
        lines = input.readlines()
        curr_id = None
        for i, line in enumerate(lines):
            line = line.strip()
            if line == '[ID]':
                curr_id = lines[i+1].strip()
                protein_dict[curr_id] = {}
                protein_dict[curr_id]['primary'] = lines[i+3].strip()
            if line == '[TERTIARY]':
                coords = []
                for j in range(3):
                    coords.append(np.fromstring(lines[i+j+1], sep='\t'))
                protein_dict[curr_id]['tertiary'] = np.array(coords)
            if line == '[MASK]':
                protein_dict[curr_id]['mask'] = lines[i+1].strip()
            if len(protein_dict.keys()) >= stop_at:
                break
    filter_seqs(protein_dict, verbose)
    return(protein_dict)

# %%
def filter_coords(coords, mask):
    mask = np.array([x=='+' for x in mask])
    mask_stretched = np.repeat(mask, 3)
    coords_filt = coords[:, mask_stretched]
    return(coords_filt)

def filter_seqs(protein_dict, verbose):
    re_chainbreak = re.compile("\-*\+*\+\-+\+\+*\-*")
    keys_to_remove = {}
    for key in protein_dict.keys():
        if len(protein_dict[key].keys()) < 3:
            keys_to_remove[key] = ' missing structure, removing...'
            continue
        mask = protein_dict[key]['mask']
        if re_chainbreak.search(mask):
            keys_to_remove[key] = " has a chainbreak, removing..."
        else:
            coords = protein_dict[key]['tertiary']
            coords_filt = filter_coords(coords, mask)
            protein_dict[key]['tertiary'] = coords_filt
    for key in keys_to_remove.keys():
        if verbose:
            print(key, keys_to_remove[key])
        del protein_dict[key]

def new_dihedral(p0, p1, p2, p3): # COPY PASTA'D FROM STACKEXCHANGE
    """Praxeolitic formula
    1 sqrt, 1 cross product"""

    b0 = -1.0*(p1 - p0)
    b1 = p2 - p1
    b2 = p3 - p2

    # normalize b1 so that it does not influence magnitude of vector
    # rejections that come next
    b1 /= np.linalg.norm(b1)

    # vector rejections
    # v = projection of b0 onto plane perpendicular to b1
    #   = b0 minus component that aligns with b1
    # w = projection of b2 onto plane perpendicular to b1
    #   = b2 minus component that aligns with b1
    v = b0 - np.dot(b0, b1)*b1
    w = b2 - np.dot(b2, b1)*b1

    # angle between v and w in a plane is the torsion angle
    # v and w may not be normalized but that's fine since tan is y/x
    x = np.dot(v, w)
    y = np.dot(np.cross(b1, v), w)
    #return np.degrees(np.arctan2(y, x))
    return np.arctan2(y, x)

def calc_angles(coords):
    N = coords.shape[1]
    angles_all = []
    for i in range(0, N-3, 3):
        psi = new_dihedral(*[coords[:, x] for x in range(i, i+4)])
        omega = new_dihedral(*[coords[:, x] for x in range(i+1, i+5)])
        phi = new_dihedral(*[coords[:, x] for x in range(i+2, i+6)])
        angles = [psi, omega, phi]
        angles_all.append(angles)
    return(np.array(angles_all))

# %%
train_proteins = read_proteinnet_file('/Users/Deathvoodoo/big_folders_msc/data/casp7/training_70', 2000, verbose=False)
val_proteins = read_proteinnet_file('/Users/Deathvoodoo/big_folders_msc/data/casp7/validation', 200, verbose=False)

# %%
# check how big the proteins are, dont wanna pad a million zeroes
keylengths_train=[len(train_proteins[key]['primary']) for key in train_proteins.keys()]
keylengths_val=[len(val_proteins[key]['primary']) for key in val_proteins.keys()]
max(max(keylengths_train), max(keylengths_val))
# Out:
# 1246

# %%
max_length = 1500
sequence_list = []
angle_list = []
for key in some_proteins.keys():
    sequence = aa_to_onehot(some_proteins[key]['primary'], aa_id_dict, some_proteins[key]['mask'])
    coords = some_proteins[key]['tertiary']
    angles = calc_angles(coords).T
    if max_length-sequence.shape[0] < 0:
        print(key, ' exceeds max length: ', max_length, ' , skipping...')
        continue
    else:
        sequence_padded = np.pad(sequence, pad_width=((0,0), (0, max_length-sequence.shape[1])), constant_values=0)
        sequence_list.append(sequence_padded)
        angles_padded = np.pad(angles, pad_width=((0,0), (0, max_length-sequence.shape[1])), constant_values=0)
        angle_list.append(angles_padded)
print(np.array(sequence_list).shape)
print(np.array(angle_list).shape)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# (805, 20, 1500)
# (805, 3, 1499)

# %%
def get_onehot_angles(protein_dict, max_length=1500):
    sequence_list = []
    angle_list = []
    for key in protein_dict.keys():
        sequence = aa_to_onehot(protein_dict[key]['primary'], aa_id_dict, protein_dict[key]['mask'])
        coords = protein_dict[key]['tertiary']
        angles = calc_angles(coords).T
        if max_length-sequence.shape[0] < 0:
            print(key, ' exceeds max length: ', max_length, ' , skipping...')
            continue
        else:
            sequence_padded = np.pad(sequence, pad_width=((0,0), (0, max_length-sequence.shape[1])), constant_values=0)
            sequence_list.append(sequence_padded)
            angles_padded = np.pad(angles, pad_width=((0,0), (0, max_length-sequence.shape[1])), constant_values=0)
            angle_list.append(angles_padded)
    N = len(sequence_list)
    have_nans = []
    for i,j in enumerate(angle_list):
        if np.isnan(j).any():
            have_nans.append(i)
    sequence_tensor = torch.tensor(sequence_list).float()
    sequence_tensor = sequence_tensor.unsqueeze(1)
    angle_tensor = torch.tensor(angle_list).float()
    angle_tensor = angle_tensor.unsqueeze(1)
    inds_to_keep = np.logical_not(np.isin(np.arange(N), have_nans))
    sequence_tensor = sequence_tensor[inds_to_keep, :, :, :]
    angle_tensor = angle_tensor[inds_to_keep, :, :, :]
    return([sequence_tensor, angle_tensor])

# %%
def split_inds(N, train_fraction, validation_fraction):
    indices = np.arange(N)
    train_to = int(np.floor(len(indices)*train_fraction))
    train_inds = indices[0: train_to]
    val_to = int(np.floor(len(indices)*(train_fraction+validation_fraction)))
    val_inds = indices[train_to: val_to]
    test_inds = indices[val_to:]
    return(train_inds, val_inds, test_inds)

# %%
train_data = get_onehot_angles(train_proteins)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide

# %%
val_data = get_onehot_angles(val_proteins)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide

# %%
from torch.utils.data import Dataset
class proteindataset(Dataset):
    def __init__(self, seqs, angles):
        self.sequences = seqs
        self.angles = angles

    def __len__(self):
        return self.sequences.shape[0]

    def __getitem__(self, idx):
        return [self.sequences[idx, :, :, :], self.angles[idx, :, :, :]]
    
class proteindataset2(Dataset): # needs to be fixed
    def __init__(self, ids):
        self.ids = ids # should be np.array
    def __len__(self):
        return len(self.ids)
    def __getitem__(self, idx):
        id_sub = self.ids[idx]
        seq_string = seqs[id_sub]['primary']
        sequence =  aa_to_onehot(seq_string, aa_id_dict, seqs[id_sub]['mask'])
        coords = seqs[id_sub]['tertiary']
        angles = calc_angles(coords).T
        seq_tensor = torch.tensor(sequence).float().unsqueeze(0)
        angle_tensor = torch.tensor(angles).float().unsqueeze(0)
        return [seq_tensor.unsqueeze(0), angle_tensor.unsqueeze(0)]

# %%
train_dataset = proteindataset(train_data[0], train_data[1])
val_dataset = proteindataset(val_data[0], val_data[1])
#test_dataset = proteindataset(test_data[0], test_data[1])

# %%
id_array = np.array(list(train_proteins.keys()))
train_dataset2 = proteindataset2(id_array)

# %%
trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=100,
                                          shuffle=True, num_workers=2)
valloader = torch.utils.data.DataLoader(val_dataset, batch_size=100,
                                         shuffle=False, num_workers=2)
#testloader = torch.utils.data.DataLoader(test_dataset, batch_size=100,
                                         #shuffle=False, num_workers=2)

# %%
trainloader2 = torch.utils.data.DataLoader(train_dataset2, batch_size=4,
                                          shuffle=True, num_workers=2)

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv0 = nn.Conv2d(1, 3, (20, 1))
        self.bnorm0 = torch.nn.BatchNorm2d(3)
        self.conv1 = nn.Conv2d(3, 6, (1, 4))
        self.bnorm1 = torch.nn.BatchNorm2d(6)
        self.conv2 = nn.Conv2d(6, 12, (1, 8))
        self.bnorm2 = torch.nn.BatchNorm2d(12)
        self.conv3 = nn.Conv2d(12, 24, (1, 12))
        self.bnorm3 = torch.nn.BatchNorm2d(24)
        
        self.deconv1 = nn.ConvTranspose2d(in_channels=24, out_channels=12, kernel_size=(1, 12))
        self.bnorm4 = torch.nn.BatchNorm2d(12)
        self.deconv2 = nn.ConvTranspose2d(in_channels=24, out_channels=6, kernel_size=(1, 8))
        self.bnorm5 = torch.nn.BatchNorm2d(6)
        self.deconv3 = nn.ConvTranspose2d(in_channels=12, out_channels=1, kernel_size=(3, 3))

    def forward(self, x):
        conv0_out = F.relu(self.bnorm0(self.conv0(x)))
        conv1_out = F.relu(self.bnorm1(self.conv1(conv0_out)))
        conv2_out = F.relu(self.bnorm2(self.conv2(conv1_out)))
        conv3_out = F.relu(self.bnorm3(self.conv3(conv2_out)))

        deconv1_out = self.bnorm4(self.deconv1(conv3_out))
        deconv2_input = torch.cat((conv2_out, deconv1_out), 1)
        deconv2_out = self.bnorm5(self.deconv2(deconv2_input))
        deconv3_input = torch.cat((conv1_out, deconv2_out), 1)
        deconv3_out = self.deconv3(deconv3_input)

        return deconv3_out

# %%
net = Net()

criterion = nn.MSELoss()
optimizer = optim.Adam(net.parameters(), lr=1e-3)
#optimizer = optim.SGD(net.parameters(), lr=1e-2)

prints_per_epoch = 3

verbose_k = np.floor(len(trainloader)/prints_per_epoch)
#print(verbose_k)

train_losses = []
val_losses = []
iterations = []
best_loss = None

for epoch in range(50):

    running_loss = 0.0
    for i, data in enumerate(trainloader):
    #for i in range(52):
        #sequence = train_data[0][i, :, :, :].unsqueeze(0)
        #true_angles = train_data[1][i, :, :, :].unsqueeze(0)
        sequence, true_angles = data
        #print(sequence.shape, true_angles.shape)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        predicted_angles = net(sequence)

        loss = criterion(predicted_angles, true_angles)
        loss.backward()
        optimizer.step()
        
        # print statistics, should add validation loss
        running_loss += loss.item()
        
        if (i+1) % verbose_k == 0:   
            train_losses.append(running_loss/verbose_k)
            true_iter = len(trainloader)*epoch + i
            iterations.append(true_iter)
            net.eval()
            validation_pred = net(val_data[0])
            validation_loss = criterion(validation_pred, val_data[1]).item()
            val_losses.append(validation_loss)
            net.train()
            print('epoch: {}, iteration: {}] training loss: {}, validation_loss: {}'.format(
                epoch, i, running_loss/verbose_k, validation_loss))
            
            if best_loss == None:
                best_loss = validation_loss
            else:
                if validation_loss <= min(val_losses):
                    print('new best validation loss, saving..')
                    best_loss = validation_loss
                    torch.save(net.state_dict(), 'best_fcn_parameters.pt')

            running_loss = 0.0

print('Finished Training')
# Out:
# epoch: 0, iteration: 4] training loss: 1.346999955177307, validation_loss: 0.6612606048583984
# epoch: 0, iteration: 9] training loss: 0.8109584212303161, validation_loss: 0.6653778553009033
# epoch: 0, iteration: 14] training loss: 0.6761969804763794, validation_loss: 0.6693404912948608
# epoch: 1, iteration: 4] training loss: 0.6468740224838256, validation_loss: 0.6719595193862915
# epoch: 1, iteration: 9] training loss: 0.5975839495658875, validation_loss: 0.6658914685249329
# epoch: 1, iteration: 14] training loss: 0.6096521139144897, validation_loss: 0.6526800394058228
# new best validation loss, saving..
# epoch: 2, iteration: 4] training loss: 0.5670120000839234, validation_loss: 0.6318108439445496
# new best validation loss, saving..
# epoch: 2, iteration: 9] training loss: 0.5541205763816833, validation_loss: 0.6133136749267578
# new best validation loss, saving..
# epoch: 2, iteration: 14] training loss: 0.5646921038627625, validation_loss: 0.594924807548523
# new best validation loss, saving..
# epoch: 3, iteration: 4] training loss: 0.515029352903366, validation_loss: 0.5749236345291138
# new best validation loss, saving..
# epoch: 3, iteration: 9] training loss: 0.5508701801300049, validation_loss: 0.5621587038040161
# new best validation loss, saving..
# epoch: 3, iteration: 14] training loss: 0.5344243049621582, validation_loss: 0.5516715049743652
# new best validation loss, saving..
# epoch: 4, iteration: 4] training loss: 0.5097227811813354, validation_loss: 0.5428355932235718
# new best validation loss, saving..
# epoch: 4, iteration: 9] training loss: 0.5289572536945343, validation_loss: 0.5379088521003723
# new best validation loss, saving..
# epoch: 4, iteration: 14] training loss: 0.5144637942314148, validation_loss: 0.5340955257415771
# new best validation loss, saving..
# epoch: 5, iteration: 4] training loss: 0.5065475821495056, validation_loss: 0.5306398868560791
# new best validation loss, saving..
# epoch: 5, iteration: 9] training loss: 0.5123748123645783, validation_loss: 0.5285604596138
# new best validation loss, saving..
# epoch: 5, iteration: 14] training loss: 0.5050772964954376, validation_loss: 0.5269206166267395
# new best validation loss, saving..
# epoch: 6, iteration: 4] training loss: 0.4980649471282959, validation_loss: 0.5249199271202087
# new best validation loss, saving..
# epoch: 6, iteration: 9] training loss: 0.5256168603897095, validation_loss: 0.5235904455184937
# new best validation loss, saving..
# epoch: 6, iteration: 14] training loss: 0.4918351650238037, validation_loss: 0.5225203037261963
# new best validation loss, saving..
# epoch: 7, iteration: 4] training loss: 0.494488400220871, validation_loss: 0.5215032696723938
# new best validation loss, saving..
# epoch: 7, iteration: 9] training loss: 0.4877139151096344, validation_loss: 0.5209525227546692
# new best validation loss, saving..
# epoch: 7, iteration: 14] training loss: 0.5252194762229919, validation_loss: 0.5198981165885925
# new best validation loss, saving..
# epoch: 8, iteration: 4] training loss: 0.4988790214061737, validation_loss: 0.5191102027893066
# new best validation loss, saving..
# epoch: 8, iteration: 9] training loss: 0.5115679919719696, validation_loss: 0.5182817578315735
# new best validation loss, saving..
# epoch: 8, iteration: 14] training loss: 0.49419012665748596, validation_loss: 0.5177737474441528
# new best validation loss, saving..
# epoch: 9, iteration: 4] training loss: 0.49383376240730287, validation_loss: 0.517259955406189
# new best validation loss, saving..
# epoch: 9, iteration: 9] training loss: 0.49391084909439087, validation_loss: 0.5168090462684631
# new best validation loss, saving..
# epoch: 9, iteration: 14] training loss: 0.5046696245670319, validation_loss: 0.5162144899368286
# new best validation loss, saving..
# epoch: 10, iteration: 4] training loss: 0.48302615284919737, validation_loss: 0.5155754089355469
# new best validation loss, saving..
# epoch: 10, iteration: 9] training loss: 0.4865092098712921, validation_loss: 0.5151577591896057
# new best validation loss, saving..
# epoch: 10, iteration: 14] training loss: 0.5178297340869904, validation_loss: 0.5147886872291565
# new best validation loss, saving..
# epoch: 11, iteration: 4] training loss: 0.4790602922439575, validation_loss: 0.5142053961753845
# new best validation loss, saving..
# epoch: 11, iteration: 9] training loss: 0.5076931416988373, validation_loss: 0.5136858820915222
# new best validation loss, saving..
# epoch: 11, iteration: 14] training loss: 0.5008448958396912, validation_loss: 0.5130979418754578
# new best validation loss, saving..
# epoch: 12, iteration: 4] training loss: 0.48840609192848206, validation_loss: 0.512675404548645
# new best validation loss, saving..
# epoch: 12, iteration: 9] training loss: 0.49735626578330994, validation_loss: 0.5122693777084351
# new best validation loss, saving..
# epoch: 12, iteration: 14] training loss: 0.49498059749603274, validation_loss: 0.5119542479515076
# new best validation loss, saving..
# epoch: 13, iteration: 4] training loss: 0.46592167019844055, validation_loss: 0.511542797088623
# new best validation loss, saving..
# epoch: 13, iteration: 9] training loss: 0.5025590419769287, validation_loss: 0.510959804058075
# new best validation loss, saving..
# epoch: 13, iteration: 14] training loss: 0.5156817674636841, validation_loss: 0.5103561282157898
# new best validation loss, saving..
# epoch: 14, iteration: 4] training loss: 0.5192355275154114, validation_loss: 0.509874701499939
# new best validation loss, saving..
# epoch: 14, iteration: 9] training loss: 0.48019376397132874, validation_loss: 0.5096330046653748
# new best validation loss, saving..
# epoch: 14, iteration: 14] training loss: 0.4767816424369812, validation_loss: 0.509228527545929
# new best validation loss, saving..
# epoch: 15, iteration: 4] training loss: 0.4649089276790619, validation_loss: 0.5089921355247498
# new best validation loss, saving..
# epoch: 15, iteration: 9] training loss: 0.5267461240291595, validation_loss: 0.5084768533706665
# new best validation loss, saving..
# epoch: 15, iteration: 14] training loss: 0.48178269863128664, validation_loss: 0.5080975890159607
# new best validation loss, saving..
# epoch: 16, iteration: 4] training loss: 0.48239482045173643, validation_loss: 0.5091326832771301
# epoch: 16, iteration: 9] training loss: 0.5053368628025054, validation_loss: 0.507610023021698
# new best validation loss, saving..
# epoch: 16, iteration: 14] training loss: 0.4931576788425446, validation_loss: 0.507934033870697
# epoch: 17, iteration: 4] training loss: 0.4902017593383789, validation_loss: 0.5071439743041992
# new best validation loss, saving..
# epoch: 17, iteration: 9] training loss: 0.4767883360385895, validation_loss: 0.5067136287689209
# new best validation loss, saving..
# epoch: 17, iteration: 14] training loss: 0.49375555515289304, validation_loss: 0.5062928199768066
# new best validation loss, saving..
# epoch: 18, iteration: 4] training loss: 0.47918136715888976, validation_loss: 0.5059241056442261
# new best validation loss, saving..
# epoch: 18, iteration: 9] training loss: 0.4803157866001129, validation_loss: 0.5056039094924927
# new best validation loss, saving..
# epoch: 18, iteration: 14] training loss: 0.5065808713436126, validation_loss: 0.5053128600120544
# new best validation loss, saving..
# epoch: 19, iteration: 4] training loss: 0.4951210618019104, validation_loss: 0.5052552223205566
# new best validation loss, saving..
# epoch: 19, iteration: 9] training loss: 0.49250327944755556, validation_loss: 0.5049687027931213
# new best validation loss, saving..
# epoch: 19, iteration: 14] training loss: 0.47267706990242003, validation_loss: 0.5051653385162354
# epoch: 20, iteration: 4] training loss: 0.49590388536453245, validation_loss: 0.5043779015541077
# new best validation loss, saving..
# epoch: 20, iteration: 9] training loss: 0.48716883063316346, validation_loss: 0.5048913359642029
# epoch: 20, iteration: 14] training loss: 0.47564520239830016, validation_loss: 0.5041435956954956
# new best validation loss, saving..
# epoch: 21, iteration: 4] training loss: 0.5026917874813079, validation_loss: 0.50424724817276
# epoch: 21, iteration: 9] training loss: 0.46554137468338014, validation_loss: 0.5036471486091614
# new best validation loss, saving..
# epoch: 21, iteration: 14] training loss: 0.49307848811149596, validation_loss: 0.5034626126289368
# new best validation loss, saving..
# epoch: 22, iteration: 4] training loss: 0.5004382312297821, validation_loss: 0.5034646987915039
# epoch: 22, iteration: 9] training loss: 0.48504036068916323, validation_loss: 0.5033885836601257
# new best validation loss, saving..
# epoch: 22, iteration: 14] training loss: 0.4726028203964233, validation_loss: 0.5033047795295715
# new best validation loss, saving..
# epoch: 23, iteration: 4] training loss: 0.48551304936408995, validation_loss: 0.5029894113540649
# new best validation loss, saving..
# epoch: 23, iteration: 9] training loss: 0.4808096647262573, validation_loss: 0.5032849311828613
# epoch: 23, iteration: 14] training loss: 0.4950728416442871, validation_loss: 0.503052294254303
# epoch: 24, iteration: 4] training loss: 0.4899945378303528, validation_loss: 0.5024398565292358
# new best validation loss, saving..
# epoch: 24, iteration: 9] training loss: 0.4932475030422211, validation_loss: 0.502608597278595
# epoch: 24, iteration: 14] training loss: 0.47263681292533877, validation_loss: 0.5028032064437866
# epoch: 25, iteration: 4] training loss: 0.47182021141052244, validation_loss: 0.5027539730072021
# epoch: 25, iteration: 9] training loss: 0.4914246678352356, validation_loss: 0.5021182894706726
# new best validation loss, saving..
# epoch: 25, iteration: 14] training loss: 0.47892066836357117, validation_loss: 0.5024779438972473
# epoch: 26, iteration: 4] training loss: 0.491371089220047, validation_loss: 0.5039166808128357
# epoch: 26, iteration: 9] training loss: 0.49435281157493594, validation_loss: 0.5021312236785889
# epoch: 26, iteration: 14] training loss: 0.4617341697216034, validation_loss: 0.5017249584197998
# new best validation loss, saving..
# epoch: 27, iteration: 4] training loss: 0.4667428731918335, validation_loss: 0.5016334056854248
# new best validation loss, saving..
# epoch: 27, iteration: 9] training loss: 0.4764394223690033, validation_loss: 0.501309335231781
# new best validation loss, saving..
# epoch: 27, iteration: 14] training loss: 0.5075423121452332, validation_loss: 0.5011447072029114
# new best validation loss, saving..
# epoch: 28, iteration: 4] training loss: 0.48105337023735045, validation_loss: 0.5010120868682861
# new best validation loss, saving..
# epoch: 28, iteration: 9] training loss: 0.49137344360351565, validation_loss: 0.5008224248886108
# new best validation loss, saving..
# epoch: 28, iteration: 14] training loss: 0.47264094948768615, validation_loss: 0.5005571842193604
# new best validation loss, saving..
# epoch: 29, iteration: 4] training loss: 0.4792173981666565, validation_loss: 0.5006679892539978
# epoch: 29, iteration: 9] training loss: 0.4924949109554291, validation_loss: 0.5004515647888184
# new best validation loss, saving..
# epoch: 29, iteration: 14] training loss: 0.46983044743537905, validation_loss: 0.5001583099365234
# new best validation loss, saving..
# epoch: 30, iteration: 4] training loss: 0.49892979860305786, validation_loss: 0.500320315361023
# epoch: 30, iteration: 9] training loss: 0.4657665312290192, validation_loss: 0.5002361536026001
# epoch: 30, iteration: 14] training loss: 0.4718664288520813, validation_loss: 0.5000958442687988
# new best validation loss, saving..
# epoch: 31, iteration: 4] training loss: 0.4604755163192749, validation_loss: 0.5002015829086304
# epoch: 31, iteration: 9] training loss: 0.5012663841247559, validation_loss: 0.4996822476387024
# new best validation loss, saving..
# epoch: 31, iteration: 14] training loss: 0.48343409299850465, validation_loss: 0.4998071491718292
# epoch: 32, iteration: 4] training loss: 0.4843004643917084, validation_loss: 0.4999304711818695
# epoch: 32, iteration: 9] training loss: 0.487815260887146, validation_loss: 0.49961698055267334
# new best validation loss, saving..
# epoch: 32, iteration: 14] training loss: 0.4649656772613525, validation_loss: 0.4997778832912445
# epoch: 33, iteration: 4] training loss: 0.47398620247840884, validation_loss: 0.49969884753227234
# epoch: 33, iteration: 9] training loss: 0.4738982915878296, validation_loss: 0.4990682601928711
# new best validation loss, saving..
# epoch: 33, iteration: 14] training loss: 0.5026348173618317, validation_loss: 0.4994540810585022
# epoch: 34, iteration: 4] training loss: 0.49185510277748107, validation_loss: 0.49923205375671387
# epoch: 34, iteration: 9] training loss: 0.47463876008987427, validation_loss: 0.4987659156322479
# new best validation loss, saving..
# epoch: 34, iteration: 14] training loss: 0.4656851887702942, validation_loss: 0.49974244832992554
# epoch: 35, iteration: 4] training loss: 0.46637882590293883, validation_loss: 0.4996001124382019
# epoch: 35, iteration: 9] training loss: 0.4994216740131378, validation_loss: 0.49942880868911743
# epoch: 35, iteration: 14] training loss: 0.4764419376850128, validation_loss: 0.4997628629207611
# epoch: 36, iteration: 4] training loss: 0.47648765444755553, validation_loss: 0.49882030487060547
# epoch: 36, iteration: 9] training loss: 0.4813313245773315, validation_loss: 0.498587965965271
# new best validation loss, saving..
# epoch: 36, iteration: 14] training loss: 0.48403599858283997, validation_loss: 0.4986107051372528
# epoch: 37, iteration: 4] training loss: 0.4923750996589661, validation_loss: 0.49835872650146484
# new best validation loss, saving..
# epoch: 37, iteration: 9] training loss: 0.4635396242141724, validation_loss: 0.498025506734848
# new best validation loss, saving..
# epoch: 37, iteration: 14] training loss: 0.48689464330673216, validation_loss: 0.4979023337364197
# new best validation loss, saving..
# epoch: 38, iteration: 4] training loss: 0.4849988043308258, validation_loss: 0.4978974461555481
# new best validation loss, saving..
# epoch: 38, iteration: 9] training loss: 0.4776779353618622, validation_loss: 0.4986623525619507
# epoch: 38, iteration: 14] training loss: 0.4744838893413544, validation_loss: 0.49757346510887146
# new best validation loss, saving..
# epoch: 39, iteration: 4] training loss: 0.47605844736099245, validation_loss: 0.4977160394191742
# epoch: 39, iteration: 9] training loss: 0.46251508593559265, validation_loss: 0.4993892014026642
# epoch: 39, iteration: 14] training loss: 0.49186702370643615, validation_loss: 0.49761858582496643
# epoch: 40, iteration: 4] training loss: 0.4773275554180145, validation_loss: 0.4970800578594208
# new best validation loss, saving..
# epoch: 40, iteration: 9] training loss: 0.48622019290924073, validation_loss: 0.49782881140708923
# epoch: 40, iteration: 14] training loss: 0.471829479932785, validation_loss: 0.4969726502895355
# new best validation loss, saving..
# epoch: 41, iteration: 4] training loss: 0.48319717645645144, validation_loss: 0.4970480799674988
# epoch: 41, iteration: 9] training loss: 0.47348284125328066, validation_loss: 0.4971213638782501
# epoch: 41, iteration: 14] training loss: 0.48242889642715453, validation_loss: 0.4972487986087799
# epoch: 42, iteration: 4] training loss: 0.4507832944393158, validation_loss: 0.49749138951301575
# epoch: 42, iteration: 9] training loss: 0.4862228870391846, validation_loss: 0.4969576299190521
# new best validation loss, saving..
# epoch: 42, iteration: 14] training loss: 0.4975566387176514, validation_loss: 0.498769074678421
# epoch: 43, iteration: 4] training loss: 0.49077885746955874, validation_loss: 0.4974975883960724
# epoch: 43, iteration: 9] training loss: 0.49233049154281616, validation_loss: 0.4973609149456024
# epoch: 43, iteration: 14] training loss: 0.45482433438301084, validation_loss: 0.4968091547489166
# new best validation loss, saving..
# epoch: 44, iteration: 4] training loss: 0.4828857958316803, validation_loss: 0.4964400827884674
# new best validation loss, saving..
# epoch: 44, iteration: 9] training loss: 0.45955321192741394, validation_loss: 0.4997650682926178
# epoch: 44, iteration: 14] training loss: 0.5007183909416199, validation_loss: 0.5071926116943359
# epoch: 45, iteration: 4] training loss: 0.48735268115997316, validation_loss: 0.500004231929779
# epoch: 45, iteration: 9] training loss: 0.47106282114982606, validation_loss: 0.49745526909828186
# epoch: 45, iteration: 14] training loss: 0.48237246870994566, validation_loss: 0.49694979190826416
# epoch: 46, iteration: 4] training loss: 0.4724901854991913, validation_loss: 0.4967430531978607
# epoch: 46, iteration: 9] training loss: 0.45143691897392274, validation_loss: 0.4961390197277069
# new best validation loss, saving..
# epoch: 46, iteration: 14] training loss: 0.5050410389900207, validation_loss: 0.49605792760849
# new best validation loss, saving..
# epoch: 47, iteration: 4] training loss: 0.4673293709754944, validation_loss: 0.49649402499198914
# epoch: 47, iteration: 9] training loss: 0.4764802038669586, validation_loss: 0.4957585632801056
# new best validation loss, saving..
# epoch: 47, iteration: 14] training loss: 0.4908961355686188, validation_loss: 0.4963066875934601
# epoch: 48, iteration: 4] training loss: 0.49053635001182555, validation_loss: 0.49575427174568176
# new best validation loss, saving..
# epoch: 48, iteration: 9] training loss: 0.4770037353038788, validation_loss: 0.4955501854419708
# new best validation loss, saving..
# epoch: 48, iteration: 14] training loss: 0.4772158443927765, validation_loss: 0.4957979619503021
# epoch: 49, iteration: 4] training loss: 0.48567832708358766, validation_loss: 0.4958939552307129
# epoch: 49, iteration: 9] training loss: 0.48113142848014834, validation_loss: 0.49604126811027527
# epoch: 49, iteration: 14] training loss: 0.4627821326255798, validation_loss: 0.4963013529777527
# Finished Training

# %%
net.load_state_dict(torch.load('/Users/Deathvoodoo/Documents/random/best_fcn_parameters.pt'))

net.eval()

validation_pred = net(val_data[0])
# Out:
# torch.Size([161, 1, 3, 1499])

# %%
import matplotlib.pyplot as plt
plt.scatter(iterations, train_losses, label='train loss')
plt.scatter(iterations, val_losses, label='validation loss')
plt.legend()
plt.show()

# %%
import PeptideBuilder
test_protein = list(val_proteins.keys())[13]
print(len(val_proteins[test_protein]['primary']))
print(val_data[0][13, 0, :, :].sum()) # sanity check, but the keys should be arranged in insertion order anyway
# Out:
# 432

# %%
test_protein
# Out:
# '30#1W26_1_A'

# %%
test_angles_read = val_data[1][13, 0, :, :]
test_angles_pred = validation_pred[13, 0, :, :].detach()[:, 0:431]

# %%
def make_pb_structure(seq_str, angles):
    psi = np.degrees(angles[0, :].tolist())
    omega = np.degrees(angles[1, :].tolist())
    phi = np.degrees(angles[2, :].tolist())
    structure = PeptideBuilder.make_structure(seq_str, phi, psi, omega)
    return(structure)

# %%
test_structure_real = make_pb_structure(val_proteins[test_protein]['primary'], val_data[1][13, 0, :, :])

# %%
test_structure_pred = make_pb_structure(val_proteins[test_protein]['primary'], test_angles_pred)

# %%
import Bio.PDB
def write_to_pdb(structure, prot_id, identifier):
    out = Bio.PDB.PDBIO()
    out.set_structure(structure)
    out.save(prot_id + identifier + ".pdb")

# %%
write_to_pdb(test_structure_real, test_protein, '_real')
write_to_pdb(test_structure_pred, test_protein, '_pred')

# %%
from IPython.display import Image 
im = Image(filename="/Users/Deathvoodoo/Documents/random/pymol_prot_fcn.png")
display(im)

# %% [markdown]
# Work in progress...
